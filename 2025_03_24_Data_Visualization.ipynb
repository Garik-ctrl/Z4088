# %% [markdown]
# <a href="https://colab.research.google.com/github/Garik-ctrl/Z4088/blob/master/2025_03_24_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img height="180px" src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" align="left" hspace="30px" vspace="50px"/>
#
# # Welcome to your next notebook with SDA!
#
# During the classes we will mostly use [Google Colaboratory](https://colab.research.google.com/?hl=en) which is a free Jupyter notebook environment that requires no setup and runs entirely in the cloud.
#
# However, for bigger projects, especially involving Deep Learning and/or big data reading, it might be a better choice to setup Jupyter Notebook or Jupyter Lab on your computer. Also, it is worth noticing that there is a great number of useful extensions (see [nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/index.html) and [jupyter-labextension](https://jupyterlab.readthedocs.io/en/stable/user/extensions.html)) not available for Colab users.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=17kfVvQMXjFhEuQEqtYvR4VtXIvFKC6G1" alt="Where are we?" title="Where are we? Intermediate Python" align="left" width="1000px" hspace="10px" vspace="10px"/>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
#
# # Data Visualization
# Start by reading through the presentation slides.
#
# <br>
#
# After the **<font color='#ed7d31'>DATA VISUALIZATION</font>** course you will be familiar with most common libraries used by Data Scientists:
# * matplotlib
# * seaborn
# * plotly
# * dash plotly
# * Practice❗

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
#
# # 1. Matplotlib
#
# **<font color='#ed7d31'>PRACTICAL WORKSHOPS WITH SCREEN SHARING BY YOUR MENTOR</font>**
#
# <img src="https://drive.google.com/uc?export=view&id=1K1wLdlAGcaaFYnpTitD2iCYPcSbEFWxc" alt="Pandas: tabular data" title="Matplotlib: logo" align="center" width="500px" hspace="30px" vspace="10px"/>
#
# * library for creating 2D and 3D graphs
# * MATLAB-like interface
# * approx. 70 thousand lines of code
# * `pyplot` module - creating graphs/plots
# * homepage with documentation:<br>https://matplotlib.org/index.html

# %%
# a magic function that renders the figure in a notebook
# (instead of displaying a dump of the figure object)
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt  # conventional alias

# equivalent to
# from matplotlib import pyplot as plt

# %% [markdown]
# ### First drawing
#
# In order to **<font color='##13e5e1'>create a plot</font>**, we commonly utilize the function `plt.subplots()`, which returns two objects:
# * `fig` - serves as a container for the plots
# * `ax/axes` - represents the actual plot/plots themselves
#
# To **<font color='##13e5e1'>incorporate visual elements</font>** onto the plot, we utilize various operations on the `ax` object, e.g. by calling methods such as `.plot()`, we can add different types of visualizations, such as line plots.
#
# Once the desired visualizations have been added, we can display the final graph by using the `plt.show()` function. It **<font color='##13e5e1'>displays the graph</font>** in a separate window or within the notebook interface.

# %%
# data to vizualize
x = [0, 1, 2, 3]
y = [0, 1, 2, 3]

# create a canva (plot container)
fig, ax = plt.subplots()
ax.plot(x, y) # line plot
ax.grid()
plt.show() # display the graph

# %% [markdown]
# To add a grid to a matplotlib plot, you can use the `.grid()` method. Such grid is a visual element that can be added to a plot to enhance its appearance and aid in data interpretation. It consists of **<font color='##13e5e1'>horizontal and vertical lines</font>** that align with the major ticks on the X-axis and Y-axis.
#
# By default, the `.grid()` function enables the gridlines with a light gray color, but you have the flexibility to **<font color='##13e5e1'>customize the grid</font>** by adjusting its appearance. The `.grid()` function accepts optional parameters such as
# * `color`
# * `linestyle`
# * `linewidth`
# * `alpha`
#
# to modify the color, line style, thickness, and transparency of the gridlines.

# %%
fig, ax = plt.subplots()

ax.grid()
plt.show()

# %%
fig,ax = plt.subplots()

ax.grid(
    color='darkgreen',
    linestyle='--',
    #linewidth=5,
    alpha=0.9
)

plt.show()

# %% [markdown]
# There are many additonal paramters, see official documentation for more: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html
#
# For example, the `axis` parameter in the `.grid()` method allows you to control which axis the gridlines are drawn on:
# * `axis='x'` to add the gridlines only along the X-axis
# * `axis='y'` to add them only along the Y-axis.
#
# To include gridlines on both axes, you can set `axis='both'` which is the default.

# %%
fig,ax = plt.subplots()

ax.grid(
    axis='x',
    color='#7bf992',
    linewidth=1.5,
)

ax.grid(
    axis='y',
    color='b',
    linewidth=1.5,
)

plt.show()

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
# <br>
#
# ## Weather in Seattle
#
# The best way to show the utility of this library is by using real data.
#
# *Instead of using the URL below, you can also download the file from: https://drive.google.com/drive/folders/1Tx2SceHPlAu6qy_ox1j1kcfw8uhELWDU?usp=drive_link*

# %%
url='https://raw.githubusercontent.com/matzim95/ML-datasets/master/weather.csv'

weather=pd.read_csv(
    url,
    parse_dates=True,
    index_col='date'
)

# %%
weather.head()
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain

# %% [markdown]
# ### Basic time series vizualization

# %%
fig, ax = plt.subplots()

# draw a plot using an "axis" object
ax.plot(weather.index, weather['temp_max'])
plt.show()

# %% [markdown]
# ### Adjust size of the canva
# Note that the labels on the chart are not readable and the default size of the chart is not optimal.

# %%
fig, ax = plt.subplots(figsize=(15, 2))

ax.plot(weather.index, weather['temp_max'])
plt.show()

# %% [markdown]
# ### Display multiple plots/layers on the same graph
#
# What if you want to draw **<font color='##13e5e1'>two or more plots on a single graph</font>** in matplotlib, allowing for visual comparison and analysis of multiple datasets or features within the same figure?

# %%
fig, ax=plt.subplots(figsize=(12, 4))

ax.plot(weather.index, weather['temp_max'], color='#7bf992')
ax.plot(weather.index, weather['temp_min'])
ax.plot(weather.index, weather['precipitation'])

plt.show()

# %% [markdown]
# ### Specify legend
#
# Note that we can only **<font color='##13e5e1'>guess which color corresponds to which column</font>**. Here it's easy because the data comes from one region (ie. Seattle) and describes the minimum and maximum temperature. What if they came from different places or described traits that would not be so obvious to distinguish based on the graph?
#
# If you want to **<font color='##13e5e1'>add legend labels to a graph</font>** in matplotlib, allowing you to distinguish and identify different datasets or plot elements in the visualization, follow these steps:
# * assign a label to each plot
# * after plotting all the necessary elements, call the `plt.legend()` function to display the legend on the graph.
#
# Customize the appearance of the legend, if desired, by using optional parameters available in the `plt.legend()` function. These parameters allow you to control the position, alignment, font size, and other properties of the legend.
#
# Display the graph using the `plt.show()` function.

# %%
fig, ax=plt.subplots(figsize=(12, 4))

ax.plot(weather.index, weather['temp_max'], label='max')
ax.plot(weather.index, weather['temp_min'], label='min')

plt.legend()
plt.show()

# %% [markdown]
# ### Markers and lines on the graph
#
# In example below, let's consider only partial data for 20 consecutive temperature values. Note, that rotaion of the X-axis ticks can also help to make them readable.

# %%
n = 20

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(
    weather.index[:n],
    weather['temp_max'][:n],
)

ax.plot(
    weather.index[:n],
    weather['temp_min'][:n],
)

plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# So far we've been using the default arguments but you can have a huge impact on what the chart you create looks like!
#
# In matplotlib, **<font color='##13e5e1'>markers and lines are used to represent data points and connect them</font>** in a plot:
# * **<font color='darkorange'>markers</font>** are symbols or shapes that represent individual data points on a plot
#  * they can be used to highlight the position of data values
#  * there is a variety of marker options, such as dots, squares, triangles, and more
#  * customization options for markers include size, color, edge color, and transparency
# * **<font color='darkorange'>lines</font>** are used to connect data points in a plot, forming continuous lines or curves - they help to visualize trends and relationships between data points
#  * common line styles include solid lines, dashed lines, dotted lines, and more
#  * you can customize line colors, widths, and transparency using parameters like color, linewidth, and alpha

# %%
n = 20

fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(
    weather.index[:n],
    weather['temp_max'][:n],
    marker='o',
    linestyle='--',
    color='r'
)

ax.plot(
    weather.index[:n],
    weather['temp_min'][:n],
    marker='v',
    linestyle='None',
    color='b'
)

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Create a chart:
# * select the last 30 observations from the `weather` collection
# * set a size of the graph
# * create a line graph for the variables `wind` and `precipitation`
# * change the marker type, color, and line type
# * add a legend with line description
#
# <img src="https://drive.google.com/uc?export=view&id=1O6FIgYMRe843hNtFk4sq3aO8H-a51_yZ" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="500px" hspace="30px" vspace="10px"/>

# %%
n = 30

fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(
    weather.index[-n:],
    weather['wind'][-n:],
    marker='x',
    linestyle=':',
    color='green'
)

ax.plot(
    weather.index[-n:],
    weather['precipitation'][-n:],
    marker='o',
    linestyle='-',
    color='pink'
)

plt.legend(["wind","precipitation"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Title and axes labels
#
# To add a **<font color='##13e5e1'>title and labels on X-axis and Y-axis</font>** to a plot in matplotlib, you can use the following steps:
# * set the title of the plot by using the `plt.title()` function. Pass the desired title as a string argument to this function.
# * set the X-label by using the `plt.xlabel()` function. Pass the desired label text as a string argument to this function. For the Y-label use `plt.ylabel()` function.
#
# Customize the appearance of the title and x-label further, if desired, by using additional optional parameters available in the corresponding functions. These parameters allow you to adjust the font size, font style, color, alignment, and other properties of the title and x-label.

# %%
n=30

fig,ax = plt.subplots(figsize=(8, 4))

ax.plot(
    weather.index[-n:],
    weather['temp_max'][-n:],
    marker='o',
    linestyle='--',
    color='r',
    label='max'
)

ax.plot(
    weather.index[-n:],
    weather['temp_min'][-n:],
    marker='v',
    linestyle='dotted',
    color='b',
    label='min'
)

ax.set_title('Temperature in Seattle - January 2012')  # plt.title()
ax.set_xlabel('Date (year/month/day)')  # plt.xlabel()
ax.set_ylabel('Temperature [centigrade]')  # plt.ylabel()
# ax.xaxis.set_tick_params(rotation=90)  # eq. to ax.xticks()

ax.legend(title='Temperature')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Modify the last chart:
# * change marker, linestyle and color parameters
# * change the tick rotation on the X axis
# * for X-axis, Y-axis and title, define the font (type, color, size)
#
# <img src="https://drive.google.com/uc?export=view&id=1OU1Bc3K8A_lqIBvlhLRLqM1Pt_ZLtfd1" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="500px" hspace="30px" vspace="10px"/>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
# <br>
#
# ## Weather in Austin
#
# *Instead of using the URL below, you can also download the file from: https://drive.google.com/drive/folders/1Tx2SceHPlAu6qy_ox1j1kcfw8uhELWDU?usp=drive_link*

# %%
url='https://raw.githubusercontent.com/matzim95/ML-datasets/master/austin_weather.csv'

austin_weather = pd.read_csv(url, parse_dates=True, index_col='Date')
austin_weather.head()
# Out:
#             TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# Date
# 2013-12-21         74        60        45            67           49
# 2013-12-22         56        48        39            43           36
# 2013-12-23         58        45        32            31           27
# 2013-12-24         61        46        31            36           28
# 2013-12-25         58        50        41            44           40
#
#            DewPointLowF HumidityHighPercent HumidityAvgPercent  \
# Date
# 2013-12-21           43                  93                 75
# 2013-12-22           28                  93                 68
# 2013-12-23           23                  76                 52
# 2013-12-24           21                  89                 56
# 2013-12-25           36                  86                 71
#
#            HumidityLowPercent SeaLevelPressureHighInches  \
# Date
# 2013-12-21                 57                      29.86
# ...

# %%
austin_weather.dtypes
# Out:
# TempHighF                      int64
# TempAvgF                       int64
# TempLowF                       int64
# DewPointHighF                 object
# DewPointAvgF                  object
# DewPointLowF                  object
# HumidityHighPercent           object
# HumidityAvgPercent            object
# HumidityLowPercent            object
# SeaLevelPressureHighInches    object
# SeaLevelPressureAvgInches     object
# SeaLevelPressureLowInches     object
# VisibilityHighMiles           object
# VisibilityAvgMiles            object
# VisibilityLowMiles            object
# WindHighMPH                   object
# WindAvgMPH                    object
# WindGustMPH                   object
# PrecipitationSumInches        object
# Events                        object
# dtype: object

# %%
n = 50
fig, ax=plt.subplots(figsize=(10, 5))

ax.plot(austin_weather.index[:n], austin_weather['TempAvgF'][:n], color='r')
ax.plot(austin_weather.index[:n], austin_weather['TempHighF'][:n], color='r', linestyle='--')
ax.plot(austin_weather.index[:n], austin_weather['TempLowF'][:n], color='r', linestyle='dotted')

ax.plot(austin_weather.index[:n], austin_weather['DewPointAvgF'][:n].astype(float), color='b')
ax.plot(austin_weather.index[:n], austin_weather['DewPointHighF'][:n].astype(float), color='b', linestyle='--')
ax.plot(austin_weather.index[:n], austin_weather['DewPointLowF'][:n].astype(float), color='b', linestyle='dotted')

plt.xlabel('Date (year-month-day)')
plt.ylabel('Temperature/Dew Point')
plt.title('Weather in Austin')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ### Subplots
#
# Subplots in matplotlib allow you to **<font color='##13e5e1'>create multiple plots within a single figure</font>**. Using the `plt.subplots()` function, you can specify the layout of subplots, access each subplot individually, plot data on each subplot, and customize them. Subplots are useful for comparing datasets or displaying different aspects of the same data.

# %%
n = 50
fig, ax = plt.subplots(2, 1,sharex=True, figsize=(10, 5))

ax[0].plot(austin_weather.index[:n], austin_weather['TempAvgF'][:n], color='r')
ax[0].plot(austin_weather.index[:n], austin_weather['TempHighF'][:n], color='r', linestyle='--')
ax[0].plot(austin_weather.index[:n], austin_weather['TempLowF'][:n], color='r', linestyle='dotted')


ax[1].plot(austin_weather.index[:n], austin_weather['DewPointAvgF'][:n].astype(float), color='b')
ax[1].plot(austin_weather.index[:n], austin_weather['DewPointHighF'][:n].astype(float), color='b', linestyle='--')
ax[1].plot(austin_weather.index[:n], austin_weather['DewPointLowF'][:n].astype(float), color='b', linestyle='dotted')

ax[1].set_xlabel('Date (year-month-day)')
ax[0].set_ylabel('Temperature')
ax[1].set_ylabel('Dew Point')

ax[0].set_title('Weather in Austin')
ax[1].xaxis.set_tick_params(rotation=45)
plt.show()

# %% [markdown]
# ### Text annotations
#
# Text annotation in matplotlib allows you to **<font color='##13e5e1'>add textual information to your plots</font>**. Using the `plt.text()` function, you can specify the text content and its position on the plot. Additionally, the `plt.annotate()` function provides more options for annotating specific data points with arrows and text. Text annotation helps provide context and explanations within your plots.

# %%
n=50
fig, ax=plt.subplots(2, 1, sharex=True, figsize=(10, 5))

ax[0].plot(austin_weather.index[:n], austin_weather['TempAvgF'][:n], color='r')
ax[0].plot(austin_weather.index[:n], austin_weather['TempHighF'][:n], color='r', linestyle='--')
ax[0].plot(austin_weather.index[:n], austin_weather['TempLowF'][:n], color='r', linestyle='dotted')


ax[1].plot(austin_weather.index[:n], austin_weather['DewPointAvgF'][:n].astype(float), color='b')
ax[1].plot(austin_weather.index[:n], austin_weather['DewPointHighF'][:n].astype(float), color='b', linestyle='--')
ax[1].plot(austin_weather.index[:n], austin_weather['DewPointLowF'][:n].astype(float), color='b', linestyle='dotted')

ax[1].set_xlabel('Date (year-month-day)')
ax[0].set_ylabel('Temperature')
ax[1].set_ylabel('Dew Point')

ax[0].set_title('Weather in Austin')
ax[1].xaxis.set_tick_params(rotation=90)

ax[1].annotate(
    'Something happened',
    xy=[pd.Timestamp('2014-01-07'),8],
    xytext=(pd.Timestamp('2014-01-11'),8),
    arrowprops={'arrowstyle':'->','color':'gray'}
)

plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Create graph based on the weather dataset for Austin:
# * for the fourth quarter of 2015
# * include temperature (avg, high, low), humidity (avg, high, low) and wind (avg, high, gust) on the graph
# * add annotation to the graph, ie. mark when the strongest windstorm was in the period under study
#
# <img src="https://drive.google.com/uc?export=view&id=1G3uFQGLK2hQ7oZh-1xEmfqgwFRwy5ZSI" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="650px" hspace="30px" vspace="10px"/>

# %%
austin_weather.index
# Out:
# DatetimeIndex(['2013-12-21', '2013-12-22', '2013-12-23', '2013-12-24',
#                '2013-12-25', '2013-12-26', '2013-12-27', '2013-12-28',
#                '2013-12-29', '2013-12-30',
#                ...
#                '2017-07-22', '2017-07-23', '2017-07-24', '2017-07-25',
#                '2017-07-26', '2017-07-27', '2017-07-28', '2017-07-29',
#                '2017-07-30', '2017-07-31'],
#               dtype='datetime64[ns]', name='Date', length=1319, freq=None)

# %%
data=austin_weather['2015-10-01':'2015-12-31']
data.head()
# Out:
#             TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# Date
# 2015-10-01         94        82        69            63           60
# 2015-10-02         89        78        67            58           50
# 2015-10-03         87        72        56            45           43
# 2015-10-04         87        73        59            50           47
# 2015-10-05         85        76        67            56           52
#
#            DewPointLowF HumidityHighPercent HumidityAvgPercent  \
# Date
# 2015-10-01           57                  73                 52
# 2015-10-02           40                  68                 45
# 2015-10-03           40                  57                 40
# 2015-10-04           44                  67                 45
# 2015-10-05           48                  57                 45
#
#            HumidityLowPercent SeaLevelPressureHighInches  \
# Date
# 2015-10-01                 30                      30.08
# ...

# %%
fig, ax=plt.subplots(3, 1, sharex=True, figsize=(10, 5))

ax[0].plot(data.index, data['TempAvgF'], color='r')
ax[0].plot(data.index, data['TempHighF'], color='r', linestyle='--')
ax[0].plot(data.index, data['TempLowF'], color='r', linestyle='dotted')


ax[1].plot(data.index, data['HumidityAvgPercent'].astype(float), color='b')
ax[1].plot(data.index, data['HumidityHighPercent'].astype(float), color='b', linestyle='--')
ax[1].plot(data.index, data['HumidityLowPercent'].astype(float), color='b', linestyle='dotted')

ax[2].plot(data.index, data['WindAvgMPH'].astype(float), color='g')
ax[2].plot(data.index, data['WindHighMPH'].astype(float), color='g', linestyle='--')
ax[2].plot(data.index, data['WindGustMPH'].astype(float), color='g', linestyle='dotted')

ax[2].set_xlabel('Date (year-month-day)')
ax[0].set_ylabel('Temperature')
ax[1].set_ylabel('Humidity')
ax[2].set_ylabel('Wind')

ax[0].set_title('Weather in Austin')
ax[2].xaxis.set_tick_params(rotation=45)

ax[2].annotate(
    'Winchura',
    xy=[pd.Timestamp('2015-10-30'),40],
    xytext=(pd.Timestamp('2015-11-01'),30),
    arrowprops={'arrowstyle':'->','color':'gray'}
)

plt.show()

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
# <br>
#
# ## Carbon dioxide ($CO_2$)

# %%
url = 'https://raw.githubusercontent.com/matzim95/ML-datasets/master/co2.csv'

co2 = pd.read_csv(url, parse_dates=True, index_col='Date')
co2
# Out:
#             Decimal Date  Average  Interpolated   Trend  Number of Days
# Date
# 1958-03-01      1958.208   315.71        315.71  314.62              -1
# 1958-04-01      1958.292   317.45        317.45  315.29              -1
# 1958-05-01      1958.375   317.50        317.50  314.71              -1
# 1958-06-01      1958.458   -99.99        317.10  314.85              -1
# 1958-07-01      1958.542   315.86        315.86  314.98              -1
# ...                  ...      ...           ...     ...             ...
# 2018-05-01      2018.375   411.24        411.24  407.91              24
# 2018-06-01      2018.458   410.79        410.79  408.49              29
# 2018-07-01      2018.542   408.71        408.71  408.32              27
# 2018-08-01      2018.625   406.99        406.99  408.90              30
# 2018-09-01      2018.708   405.51        405.51  409.02              29
#
# [727 rows x 5 columns]

# %%
fig,ax=plt.subplots()

ax.plot(
    co2.index,
    co2.Interpolated
)

ax.set_xlabel('Time')
ax.set_ylabel('CO2')
plt.show()

# %%
rok_97 = co2["1997":"1997"]

fig, ax=plt.subplots()

ax.plot(
    rok_97.index,
    rok_97.Interpolated
)

ax.set_xlabel('Time')
ax.set_ylabel('CO2')
plt.show()

# %% [markdown]
# *Instead of using the URL below, you can also download the file from: https://drive.google.com/drive/folders/1Tx2SceHPlAu6qy_ox1j1kcfw8uhELWDU?usp=drive_link*

# %%
url='https://raw.githubusercontent.com/matzim95/ML-datasets/master/temperature.csv'

temperature = pd.read_csv(url, parse_dates=True, index_col='dt')
temperature.index.names = ['Date']
temperature.City.unique()
# Out:
# array(['Abidjan', 'Addis Abeba', 'Ahmadabad', 'Aleppo', 'Alexandria',
#        'Ankara', 'Baghdad', 'Bangalore', 'Bangkok', 'Belo Horizonte',
#        'Berlin', 'Bogotá', 'Bombay', 'Brasília', 'Cairo', 'Calcutta',
#        'Cali', 'Cape Town', 'Casablanca', 'Changchun', 'Chengdu',
#        'Chicago', 'Chongqing', 'Dakar', 'Dalian', 'Dar Es Salaam',
#        'Delhi', 'Dhaka', 'Durban', 'Faisalabad', 'Fortaleza', 'Gizeh',
#        'Guangzhou', 'Harare', 'Harbin', 'Ho Chi Minh City', 'Hyderabad',
#        'Ibadan', 'Istanbul', 'Izmir', 'Jaipur', 'Jakarta', 'Jiddah',
#        'Jinan', 'Kabul', 'Kano', 'Kanpur', 'Karachi', 'Kiev', 'Kinshasa',
#        'Lagos', 'Lahore', 'Lakhnau', 'Lima', 'London', 'Los Angeles',
#        'Luanda', 'Madras', 'Madrid', 'Manila', 'Mashhad', 'Melbourne',
#        'Mexico', 'Mogadishu', 'Montreal', 'Moscow', 'Nagoya', 'Nagpur',
#        'Nairobi', 'Nanjing', 'New Delhi', 'New York', 'Paris', 'Peking',
# ...

# %%
temperature.head()
# Out:
#             AverageTemperature  AverageTemperatureUncertainty     City  \
# Date
# 1849-01-01              26.704                          1.435  Abidjan
# 1849-02-01              27.434                          1.362  Abidjan
# 1849-03-01              28.101                          1.612  Abidjan
# 1849-04-01              26.140                          1.387  Abidjan
# 1849-05-01              25.427                          1.200  Abidjan
#
#                   Country Latitude Longitude
# Date
# 1849-01-01  Côte D'Ivoire    5.63N     3.23W
# 1849-02-01  Côte D'Ivoire    5.63N     3.23W
# 1849-03-01  Côte D'Ivoire    5.63N     3.23W
# 1849-04-01  Côte D'Ivoire    5.63N     3.23W
# 1849-05-01  Côte D'Ivoire    5.63N     3.23W

# %%
paris = temperature[temperature.City == 'Paris']
paris
# Out:
#             AverageTemperature  AverageTemperatureUncertainty   City Country  \
# Date
# 1743-11-01               7.648                          1.749  Paris  France
# 1743-12-01                 NaN                            NaN  Paris  France
# 1744-01-01                 NaN                            NaN  Paris  France
# 1744-02-01                 NaN                            NaN  Paris  France
# 1744-03-01                 NaN                            NaN  Paris  France
# ...                        ...                            ...    ...     ...
# 2013-05-01              11.703                          0.282  Paris  France
# 2013-06-01              16.340                          0.271  Paris  France
# 2013-07-01              21.186                          0.381  Paris  France
# 2013-08-01              19.235                          0.399  Paris  France
# 2013-09-01                 NaN                            NaN  Paris  France
#
#            Latitude Longitude
# Date
# ...

# %%
merged = pd.merge(co2, paris, how='inner', on='Date')
merged
# Out:
#             Decimal Date  Average  Interpolated   Trend  Number of Days  \
# Date
# 1958-03-01      1958.208   315.71        315.71  314.62              -1
# 1958-04-01      1958.292   317.45        317.45  315.29              -1
# 1958-05-01      1958.375   317.50        317.50  314.71              -1
# 1958-06-01      1958.458   -99.99        317.10  314.85              -1
# 1958-07-01      1958.542   315.86        315.86  314.98              -1
# ...                  ...      ...           ...     ...             ...
# 2013-05-01      2013.375   399.78        399.78  396.40              28
# 2013-06-01      2013.458   398.61        398.61  396.28              26
# 2013-07-01      2013.542   397.32        397.32  396.92              21
# 2013-08-01      2013.625   395.20        395.20  397.08              27
# 2013-09-01      2013.708   393.45        393.45  396.99              27
#
#             AverageTemperature  AverageTemperatureUncertainty   City Country  \
# Date
# ...

# %%
fig, ax = plt.subplots()

ax.plot(merged.index, merged.Interpolated)
ax.plot(merged.index, merged.AverageTemperature)

ax.set_xlabel('Time')
ax.set_ylabel('CO2/Temperature')
plt.show()

# %% [markdown]
# ### Two distinct scales on Y-axis

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(
    merged.index,
    merged.Interpolated,color='b'
)
ax.set_xlabel('Time')
ax.set_ylabel('$CO_2$', color='b')
ax.tick_params('y', color='b', labelcolor='b')

# clone Y-axis (leave X-axis as shared one)
ax2 = ax.twinx()
ax2.plot(
    merged.index,
    merged.AverageTemperature.rolling(window=365, center=True,min_periods=0).mean(),
    color='r'
)
ax2.set_ylabel('Temperature', color='r')
ax2.tick_params('y', color='r', labelcolor='r')

plt.show()

# %% [markdown]
# ### Create charts using pre-defined custom functions

# %%
def plot_timeseries(axis, x, y, color, xlabel, ylabel):
  axis.plot(x, y, color)
  axis.set_xlabel(xlabel)
  axis.set_ylabel(ylabel, color=color)
  axis.tick_params('y', colors=color, labelcolor=color)

# %%
fig,ax = plt.subplots()

plot_timeseries(
    axis=ax,
    x=merged.index,
    y=merged.Trend,
    color='r',
    xlabel='Time',
    ylabel='CO2'
)

ax2=ax.twinx()
plot_timeseries(
    axis=ax2,
    x=merged.index,
    y=merged.AverageTemperature,
    color='b',
    xlabel='Time',
    ylabel='Temperature'
)

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Using weather data from Seattle (`weather.csv`), create a graph showing precipitation and wind strength in 2014.
#
# Take care of the aesthetics of the graph (graph caption, axes, font format, maybe divide into 2 sub-charts, marker format).
#
# <img src="https://drive.google.com/uc?export=view&id=1JKuq1bjzfEFJ2ZQIwyIAzp_Y9nIJKkAf" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="750px" hspace="30px" vspace="10px"/>
#
# *Hint: use `plt.tight_layout()`*

# %%
weather_seattle2014=weather[(weather.index>='2014-01-01') & (weather.index<='2014-12-31')]

# %% [markdown]
# Dohledat příkaz na fonty

# %%
fig, ax=plt.subplots(2, 1, sharex=True, figsize=(10, 4))

ax[0].plot(weather_seattle2014.index, weather_seattle2014['precipitation'], color='r', marker='o', markerfacecolor="black", markeredgecolor="black")
ax[1].plot(weather_seattle2014.index, weather_seattle2014['wind'].astype(float), color='g',marker='s', linestyle=":" )

#title_font = {'fontsize': 14, 'fontweight': 'bold'}

ax[1].set_ylabel('wind')


title_font = {'family': 'Arial',
              'color':  'darkblue',
              'weight': 'bold',
              'size': 16,
             }

ax[0].set_title('Weather in Seattle - 2014', fontdict=title_font)
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Times
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Times
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Times
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Times
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Times
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Times
# ...

# %%
weather.tail()
# Out:
#             precipitation  temp_max  temp_min  wind weather
# date
# 2015-12-27            8.6       4.4       1.7   2.9     fog
# 2015-12-28            1.5       5.0       1.7   1.3     fog
# 2015-12-29            0.0       7.2       0.6   2.6     fog
# 2015-12-30            0.0       5.6      -1.0   3.4     sun
# 2015-12-31            0.0       5.6      -2.1   3.5     sun

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
# <br>
#
# ## Bar charts
#
# Bar charts is another popular type of visualization used to **<font color='##13e5e1'>represent categorical data with rectangular bars</font>**.
#
# To create a bar chart, use the `plt.bar()` function. Provide the categorical values as the X-axis coordinates and the corresponding numerical values as the height of the bars.
#
# Bar charts are commonly used to display survey results, sales data, or any data with distinct categories. Matplotlib provides flexibility in customizing the appearance of bar charts, allowing you to create visually appealing and informative visualizations.
#
# *Instead of using the URL below, you can also download the file from: https://drive.google.com/drive/folders/1Tx2SceHPlAu6qy_ox1j1kcfw8uhELWDU?usp=drive_link*

# %%
url='https://raw.githubusercontent.com/matzim95/ML-datasets/master/population.csv'

population = pd.read_csv(url, index_col='City')
population.head()
# Out:
#               Country or Area  Year   Area         Sex    City type  \
# City
# Bialystok              Poland  2017  Total  Both Sexes  City proper
# Bielsko-Biala          Poland  2017  Total  Both Sexes  City proper
# Bydgoszcz              Poland  2017  Total  Both Sexes  City proper
# Bytom                  Poland  2017  Total  Both Sexes  City proper
# Chorzów                Poland  2017  Total  Both Sexes  City proper
#
#                       Record Type             Reliability  Source Year  \
# City
# Bialystok      Estimate - de jure  Final figure, complete         2018
# Bielsko-Biala  Estimate - de jure  Final figure, complete         2018
# Bydgoszcz      Estimate - de jure  Final figure, complete         2018
# Bytom          Estimate - de jure  Final figure, complete         2018
# Chorzów        Estimate - de jure  Final figure, complete         2018
#
#                 Value Value Footnotes
# City
# Bialystok      294362             1,2
# ...

# %%
population_by_sex = population.groupby('Sex')
both, female, male = [population_by_sex.get_group(x) for x in population_by_sex.groups]

# %%
female = population[population.Sex == 'Female']
male = population[population.Sex == 'Male']
both = population[population.Sex == 'Both Sexes']

# %%
female

# %%
# all together
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(both.index,both['Value'])

ax.xaxis.set_tick_params(rotation=90)
ax.set_ylabel('Population')
plt.show()

# %% [markdown]
# If you have **<font color='##13e5e1'>multiple categories to compare</font>**, you can plot grouped or stacked bar charts by providing appropriate values to the width and bottom parameters of the `plt.bar()` function.

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.serif'] = ['Times New Roman', 'DejaVu Serif']
plt.rcParams['font.family'] = 'serif'

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(male.index, male['Value'], label='Male')
ax.bar(female.index, female['Value'], label='Female', bottom=male['Value'])

ax.xaxis.set_tick_params(rotation=90)
ax.set_ylabel('Population')

ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(female.index, female['Value']/both['Value'], label='Female')
ax.bar(male.index, male['Value']/both['Value'], label='Male', bottom=female['Value']/both['Value'])
plt.axhline(0.5, color="red")

ax.xaxis.set_tick_params(rotation=90)
ax.set_ylabel('Population')

ax.legend()
plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Create bar chart with distribution of men and women in Polish cities:
# * on the X-axis, mark the cities
# * on the Y-axis, the percentage share of a given gender in the entire population
#
# Use stacked bar plots (for a given city, one bar on top of another).
#
# Also, add a horizontal line of 0.5.
#
# <img src="https://drive.google.com/uc?export=view&id=1XMwrPnzmKtbiG98NaO7Z3KgSxcjy9mKW" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="750px" hspace="30px" vspace="10px"/>
#
# *Hint: use `plt.axhline()`*

# %%
fig, ax = plt.subplots(figsize=(10, 6))


ax.bar(female.index, female['Value']/both['Value'], label='Female')
ax.bar(male.index, male['Value']/both['Value'], label='Male', bottom=female['Value']/both['Value'])
ax.axhline(y=0.5, color='red', linewidth=2)

ax.xaxis.set_tick_params(rotation=90)
ax.set_ylabel('Population')

ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(male.index, male['Value'], label='Male')
ax.bar(female.index, female['Value'], label='Female', bottom=male['Value'])

ax.xaxis.set_tick_params(rotation=90)
ax.set_ylabel('Population')

ax.legend()
plt.axhline()
plt.show()

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=141XOz6N4nk8Ru1sAl7vOsAToCLrSFCAX" alt="SDA logo" width="150" align='right'/>
# <br>
#
# ## Histograms
#
# A histogram is a **<font color='##13e5e1'>graphical representation of the distribution of a dataset</font>**. It provides a visual summary of the underlying frequency or probability distribution of a set of continuous or discrete data.
#
# Histograms are commonly used in data analysis and exploratory data visualization. They allow for a quick assessment of the distribution of data and can highlight important features, such as outliers or clustering tendencies. Histograms are especially useful for analyzing continuous numerical data, such as exam scores, population densities, or rainfall measurements.

# %%
url = 'https://raw.githubusercontent.com/matzim95/ML-datasets/master/olympic.csv'

medals = pd.read_csv(url, index_col='Year')
medals.head()
# Out:
#       ID                      Name Sex   Age  Height  Weight            Team  \
# Year
# 1992   1                 A Dijiang   M  24.0   180.0    80.0           China
# 2012   2                  A Lamusi   M  23.0   170.0    60.0           China
# 1920   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 1900   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 1988   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#       NOC        Games  Season       City          Sport  \
# Year
# 1992  CHN  1992 Summer  Summer  Barcelona     Basketball
# 2012  CHN  2012 Summer  Summer     London           Judo
# 1920  DEN  1920 Summer  Summer  Antwerpen       Football
# 1900  DEN  1900 Summer  Summer      Paris     Tug-Of-War
# 1988  NED  1988 Winter  Winter    Calgary  Speed Skating
#
#                                  Event Medal
# Year
# 1992       Basketball Men's Basketball   NaN
# 2012      Judo Men's Extra-Lightweight   NaN
# ...

# %%
def get_dict_with_grouped_data(df, column):
  groupby = df.groupby(column)
  return {x: groupby.get_group(x) for x in groupby.groups}

# %%
all_sports = get_dict_with_grouped_data(medals, 'Sport')

all_sports['Basketball']
# Out:
#           ID                                Name Sex   Age  Height  Weight  \
# Year
# 1992       1                           A Dijiang   M  24.0   180.0    80.0
# 2008      69                   Tamara Abalde Daz   F  19.0   185.0    72.0
# 1952     124               Youssef Mohamed Abbas   M  31.0     NaN     NaN
# 2000     136                    Alessandro Abbio   M  29.0   195.0    85.0
# 1972     192  Ahmed El-Sayed Abdel Hamid Mobarak   M  25.0   189.0    85.0
# ...      ...                                 ...  ..   ...     ...     ...
# 2004  135401                  Eurelijus ukauskas   M  30.0   218.0   115.0
# 1996  135402                  Mindaugas ukauskas   M  20.0   201.0   100.0
# 2004  135402                  Mindaugas ukauskas   M  28.0   201.0   100.0
# 2008  135530                      Philip Zwiener   M  23.0   202.0    98.0
# 2016  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
fig,ax = plt.subplots()

ax.bar('Gymnastics', all_sports['Gymnastics']['Height'].mean())
ax.bar('Basketball', all_sports['Basketball']['Height'].mean())

ax.set_ylabel('Height [cm]')
plt.show()

# %%
fig,ax=plt.subplots()

ax.hist(
    all_sports['Gymnastics']['Height'],
    label='Gymnastics',
    bins=20,
    alpha=0.6
)
ax.hist(
    all_sports['Basketball']['Height'],
    label='Basketball',
    bins=20,
    alpha=0.6
)

ax.set_xlabel('Height [cm]')
ax.set_ylabel('Number of observations')
ax.legend()
plt.show()

# %%
fig,ax=plt.subplots()

ax.hist(
    all_sports['Volleyball']['Height'],
    label='Volleyball',
    bins=40,
    alpha=0.6
)
ax.hist(
    all_sports['Table Tennis']['Height'],
    label='Table Tennis',
    bins=40,
    alpha=0.6
)

ax.hist(
    all_sports['Tennis']['Height'],
    label='Tennis',
    bins=40,
    edgecolor='green', facecolor="none",
    alpha=0.6
)


ax.set_ylabel('Height [cm]')
ax.set_xlabel('Number of observations')
ax.legend()
plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Create a graph with histogram of player growth for 3 sports:
# * experiment with the `bins` parameter (number of bars) and choose the best one according to you
# * change the appearance of the chart
#  * add a title
#  * change the font of the captions
#  * optionally, change the orientation of the chart
#  * modify the appearance of the bars
#  * etc.
#
# <img src="https://drive.google.com/uc?export=view&id=1xZ9uzqBfnF-L1YgTnwpWuFbLLs-CJHxs" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="750px" hspace="30px" vspace="10px"/>

# %%
fig,ax=plt.subplots(figsize=(10,10))

ax.hist(
    all_sports['Volleyball']['Height'],
    label='Volleyball',
    bins=40,
    alpha=0.6
)
ax.hist(
    all_sports['Table Tennis']['Height'],
    label='Table Tennis',
    bins=40,
    alpha=0.6
)
ax.hist(
    all_sports['Tennis']['Height'],
    label='Tennis', edgecolor='green', facecolor="none",histtype='step',
    bins=40,
    alpha=0.6
)

ax.set_xlabel('Height [cm]')
ax.set_ylabel('Number of observations')
ax.legend()
plt.show()

# %% [markdown]
# ## Error bars (in barplots & lineplots)
#
# Error bars are used to **<font color='##13e5e1'>represent the uncertainty or variability</font>** associated with the data points. They provide a visual indication of the confidence intervals, standard errors, or standard deviations around the mean or median values.
#
# Here's how to add error bars to a bar/line plot in matplotlib:

# %%
fig, ax = plt.subplots()

ax.bar(
    'Gymnastics',
    all_sports['Gymnastics']['Height'].mean(),
    yerr=all_sports['Gymnastics']['Height'].std()*2
)
ax.bar(
    'Basketball',
    all_sports['Basketball']['Height'].mean(),
    yerr=all_sports['Basketball']['Height'].std()*2
)

ax.set_ylabel('Height [cm]')
plt.show()

# %%
try:
    display(austin_weather.head())
except NameError:
    url='https://raw.githubusercontent.com/matzim95/ML-datasets/master/austin_weather.csv'

    austin_weather = pd.read_csv(url, parse_dates=True, index_col='Date')
    display(austin_weather.head())
# Out:
#             TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# Date
# 2013-12-21         74        60        45            67           49
# 2013-12-22         56        48        39            43           36
# 2013-12-23         58        45        32            31           27
# 2013-12-24         61        46        31            36           28
# 2013-12-25         58        50        41            44           40
#
#            DewPointLowF HumidityHighPercent HumidityAvgPercent  \
# Date
# 2013-12-21           43                  93                 75
# 2013-12-22           28                  93                 68
# 2013-12-23           23                  76                 52
# 2013-12-24           21                  89                 56
# 2013-12-25           36                  86                 71
#
#            HumidityLowPercent SeaLevelPressureHighInches  \
# Date
# 2013-12-21                 57                      29.86
# ...

# %%
n = 30
fig, ax = plt.subplots(figsize=(10, 4))

ax.errorbar(
    austin_weather.index[:n],
    austin_weather['TempAvgF'][:n],
    yerr=(austin_weather['TempHighF'][:n] - austin_weather['TempLowF'][:n])
)

ax.set_ylabel('Temperature')
ax.set_title('Weather in Austin')
ax.xaxis.set_tick_params(rotation=30)
plt.show()

# %% [markdown]
# ## Box plot
#
# A box plot, also known as a box-and-whisker plot, is another **<font color='##13e5e1'>graphical representation of the distribution</font>** of a dataset. It provides a summary of key statistical measures, including the median, quartiles, and potential outliers.
#
# Here's how to create box plot in matplotlib:

# %%
fig, ax = plt.subplots()

ax.boxplot([
    all_sports['Gymnastics']['Height'].dropna(),
    all_sports['Basketball']['Height'].dropna()
])

ax.set_xticklabels(['Gymnastics', 'Basketball'])
ax.set_ylabel('Height [cm]')
plt.show()

# %% [markdown]
# ## Scatter plot
#
# A scatter plot is a type of **<font color='##13e5e1'>plot that displays the relationship between two numerical variables</font>**. It represents individual data points as dots on a two-dimensional coordinate system.
#
# Here's an example of how to create a scatter plot:

# %%
try:
    merged.head()
except NameError:
    url = 'https://raw.githubusercontent.com/matzim95/ML-datasets/master/co2.csv'
    co2 = pd.read_csv(url, parse_dates=True, index_col='Date')

    url='https://raw.githubusercontent.com/matzim95/ML-datasets/master/temperature.csv'
    temperature = pd.read_csv(url, parse_dates=True, index_col='dt')
    temperature.index.names=['Date']

    paris=temperature[temperature.City=='Paris']

    merged = pd.merge(co2, paris, how='inner', on='Date')

# %%
fig, ax = plt.subplots()
ax.scatter(merged['Interpolated'], merged['AverageTemperature'])

ax.set_xlabel('CO2')
ax.set_ylabel('Temperature')
plt.show()

# %%
merged.index
# Out:
# DatetimeIndex(['1958-03-01', '1958-04-01', '1958-05-01', '1958-06-01',
#                '1958-07-01', '1958-08-01', '1958-09-01', '1958-10-01',
#                '1958-11-01', '1958-12-01',
#                ...
#                '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01',
#                '2013-04-01', '2013-05-01', '2013-06-01', '2013-07-01',
#                '2013-08-01', '2013-09-01'],
#               dtype='datetime64[ns]', name='Date', length=667, freq=None)

# %%
fig, ax = plt.subplots()
im = ax.scatter(
    merged['Interpolated'],
    merged['AverageTemperature'],
    c=merged.index
)

ax.set_xlabel('CO2')
ax.set_ylabel('Temperature')
fig.colorbar(im, ax=ax)
plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Create a point graph (scatter plot) of $CO_2$ dependence on temperature:
# * color-code the points by year: 60, 70, 80, 90, 00 and 10
#
# *Hint - create an additional column based on `Date`, which will indicate from which years the observation is.
#
# <img src="https://drive.google.com/uc?export=view&id=1iXzUShuU9LtEw_OkMSnkl0CvpCYQStDL" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="750px" hspace="30px" vspace="10px"/>

# %%
merged['desetileti']=(merged['Decimal Date']//10)*10
# Out:
# <ipython-input-118-7fdda60a10d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['desetileti']=(merged['Decimal Date']//10)*10

# %%
fig, ax = plt.subplots()
im = ax.scatter(
    merged['Interpolated'],
    merged['AverageTemperature'],
    c=merged['Desetiletí'],
    cmap='prism'
)

ax.set_xlabel('CO2')
ax.set_ylabel('Temperature')
#fig.colorbar(im, ax=ax)
plt.show()

# %% [markdown]
# ## Save a graph
#
# To save a graph created using matplotlib, you can use the `plt.savefig()` function. Here's how you can do it:
# * after creating your graph, add the following line of code before calling `plt.show()` or at the end of your script
# ```python
# plt.savefig('filename.png')
# ```
# Replace `'filename.png'` with the desired name, file extension and path to the file. You can specify various file formats such as PNG, JPEG, PDF, SVG, etc.
#
# Make sure to include the appropriate path if you want to save the graph in a specific directory. For example, `'path/to/save/directory/filename.png'`.

# %%
fig.set_size_inches([10,6])
fig.savefig('temp_co2_60_10.png')

# %% [markdown]
# The `plt.savefig()` function provides additional parameters that allow you to customize the saved figure. Here are some commonly used parameters:
# * `dpi` (dots per inch): Specifies the resolution or quality of the saved figure. Higher values result in a higher-resolution image
# * `bbox_inches`: Controls the portion of the figure to save. By default, it saves the entire figure, but you can specify different options like 'tight' to remove the extra whitespace around the plot. Example: plt.savefig('filename.png', bbox_inches='tight')
# * `transparent`: Determines if the saved figure has a transparent background.
# * `pad_inches`: Adds padding around the saved figure to prevent elements from being cut off. You can specify the amount of padding in inches. Example: plt.savefig('filename.png', pad_inches=0.5)

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
# <br>
#
# # TASKS

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>1.1</font>**
#
# Create a function to create a dot plot (scatter plot) with X-axis, Y-axis and 3rd dimension - color of points. Call the function on any 2 datasets we have been working on.

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>1.2</font>**
#
# Create a box plot for a weather dataset showing the distribution of precipitation by weather type.

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>1.3</font>**
#
# Create a bar chart with error bars for a weather dataset showing average precipitation by weather type, as error bars show standard deviation from average precipitation.

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>1.4</font>**
#
# Create a grouped graph showing 5 selected cities and the number of men and women in each city.
#
# Modify the ticks on the Y-axis (e.g., add commas after thousands), add values above the bars.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
#
# # 2. Seaborn
#
# Seaborn is a Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics.
#
# <img src="https://drive.google.com/uc?export=view&id=1iYWtn_YCfkk30BHSvPHgKZi6UUN0kPwA" alt="Seaborn: tabular data" title="Seaborn: logo" align="center" width="500px" hspace="30px" vspace="10px"/>
#
# Here are some key points about Seaborn:
# * **<font color='##13e5e1'>simplified syntax</font>**: optimized functions and default settings for common plot types, it allows you to create visually appealing plots with minimal code
# * **<font color='##13e5e1'>statistical visualizations</font>**: this library is particularly useful for exploring relationships between variables, visualizing distributions, and highlighting patterns in data. Additionaly, it extends Matplotlib's capabilities by providing additional statistical functionalities. It includes features such as regression plot, correlation heatmap, categorical plots, time series visualization, and support for statistical annotations.
# * **<font color='##13e5e1'>Integration with Pandas</font>**: it seamlessly integrates with the popular data manipulation library Pandas, it can directly accept Pandas DataFrames as input, making it convenient for working with tabular data
# * **<font color='##13e5e1'>Attractive default styles</font>**: it comes with aesthetically pleasing default styles and color palettes
#
# Overall, Seaborn is a powerful library for data visualization, particularly in the realm of statistical graphics. It complements Matplotlib and Pandas, making it easier to create beautiful and informative visualizations with minimal effort.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython.display import display
pd.plotting.register_matplotlib_converters()

# %% [markdown]
# *Instead of using the URL below, you can also download the file from: https://drive.google.com/drive/folders/1Tx2SceHPlAu6qy_ox1j1kcfw8uhELWDU?usp=drive_link*

# %%
url = 'https://raw.githubusercontent.com/matzim95/ML-datasets/master/wine.csv'
wine = pd.read_csv(url)
wine.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline Class
# ...

# %% [markdown]
# ## Scatter plot with regression model
#
# The biggest advantage of using Seaborn is the variety of functions for creating graphs. For example, **<font color='##13e5e1'>creating a scatter plot combined with a regression model</font>** is just one line of code using the `sns.lmplot()` function.
#
# This can be done in two ways:
# * The first (recommended) way is to pass a DataFrame to the data argument while passing column names to the x and y arguments.
# * The second way is to pass the data series directly to the axis arguments. - **<font color='red'>deprecated</font>**

# %%
sns.lmplot(x='Alcohol', y='Magnesium', data=wine)
plt.show()

# %% [markdown]
# In fact, Seaborn does not have a dedicated scatter plot function. To create this graph, we use the Seaborn function `sns.lmplot()` to fit and plot the regression line.
#
# Fortunately, each plot function has some useful options that can be set. Here's how we can adjust the lmplot() function to your needs:
# * set `fit_reg = False` to remove the regression line, since we want a scatter plot
# * set `hue = 'Class'` to color our points according to the class of the example.

# %%
sns.lmplot(
    x='Alcohol',
    y='Magnesium',
    data=wine,
    #fit_reg=False,
    hue='Class'
)

plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Using the seaborn library, create a scatter plot showing the relationship between alcohol concentration and color intensity:
# * specify the class of wine as the category
# * include a linear regression line for each wine class separately
# * format the graph
#     * add axis descriptions, title,
#     * change the rotation of values on the X-axis,
#     * add a grid on the graph.
#
# <img src="https://drive.google.com/uc?export=view&id=1Mc0N-nUTgqO_HhzJIvpHgN-95a12aPWL" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="750px" hspace="30px" vspace="10px"/>

# %%
sns.lmplot(
    x='Alcohol',
    y='Color intensity',
    data=wine,
    #fit_reg=False,
    hue='Class'
)

plt.show()

# %%
import numpy as np
plt.figure(figsize=(12, 6))
g=sns.lmplot(
    x='Alcohol',
    y='Color intensity',
    data=wine,
    hue='Class'
)
plt.title('Alcohol vs Color intensity')
plt.grid()
g.set(
    xlim=(10.5, 15.5),
    xticks=np.arange(10.5, 15.51, 0.5))
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Box plot

# %%
# wine.iloc[:,5:-2]

# %%
wine
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
g=sns.boxplot(data=wine.iloc[:, 5: -2])
g.xaxis.set_tick_params(rotation=90)

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Create a boxplot chart in the seaborn package in which you show how the alcohol content varies by wine grade.
#
# <img src="https://drive.google.com/uc?export=view&id=1pYMawR-A-Cayk4aYRk39IWZwDkL6JZsN" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="750px" hspace="30px" vspace="10px"/>

# %%
plt.figure(figsize=(6, 4))

sns.boxplot(x='Class',
            y='Alcohol',
            data=wine,
            palette=["#76b536", "#f5da42", "#b39ddb"],
            hue='Class',
            flierprops={"marker": "D", "markersize": 4,'markerfacecolor': 'gray'} )
plt.grid(False)

plt.show()

# %% [markdown]
# ## Violin plot
#
# Another advantage of Seaborn is that it has **<font color='##13e5e1'>predefined styles</font>**. The default one is "darkgrid."
#
# Here we have changed the style from the default `"whitegrid"` to `"darkgrid"` when creating a violin chart. Such a graph shows the distribution of values in a similiar but slightly different way than a boxplot.

# %%
sns.set_style('whitegrid')
sns.violinplot(x='Class', y='Alcohol', data=wine)
plt.show()

# %% [markdown]
# Violin charts are great for visualizing distribution. However, because there are only 170 wines in our dataset, we can simply display each point - with swarmplot showing the position of each point and stacking those with similar values.

# %%
sns.swarmplot(x='Class', y='Alcohol', data=wine, hue='Class')
plt.show()

# %% [markdown]
# Combine the best of several types of charts and libraries:
# * First, enlarge our figure with Matplotlib.
# * Next, plot a violinplot with the parameter `inner=None`.
# * Inside the violinplot, draw a swarmplot with black dots.
# * Finally, set the title using Matplotlib.

# %%
sns.set_style('whitegrid')

sns.violinplot(x='Class', y='Alcohol', data=wine, inner=None)
sns.swarmplot(x='Class', y='Alcohol', data=wine, color='k', alpha=0.7)

plt.ylim([10.5, 15.5])
plt.title('Alcohol according to the type of wine')
plt.show()

# %% [markdown]
# We could certainly repeat the creation of this chart for each feature. However, we can also combine this information into a single column using the `pd.melt()` function.
#
# Now, we can plot the swarmplot using melted_df, but this time with `x="stat"` and `y="value"`, so our graphs will be separated. The `hue = "Class"` attribute allows us to color the points according to the type of wine.

# %%
wine.columns
# Out:
# Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
#        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline', 'Class'],
#       dtype='object')

# %%
wine
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
melted_df = pd.melt(
    wine[[
        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
        'Proanthocyanins', 'Color intensity', 'Hue',
        'OD280/OD315 of diluted wines', 'Class'
    ]],
    id_vars='Class',
    var_name='stat'
)
melted_df
# Out:
#       Class                          stat  value
# 0       one                 Total phenols   2.80
# 1       one                 Total phenols   2.65
# 2       one                 Total phenols   2.80
# 3       one                 Total phenols   3.85
# 4       one                 Total phenols   2.80
# ...     ...                           ...    ...
# 1241  three  OD280/OD315 of diluted wines   1.74
# 1242  three  OD280/OD315 of diluted wines   1.56
# 1243  three  OD280/OD315 of diluted wines   1.56
# 1244  three  OD280/OD315 of diluted wines   1.62
# 1245  three  OD280/OD315 of diluted wines   1.60
#
# [1246 rows x 3 columns]

# %%
import warnings
# warnings.simplefilter('always', category=UserWarning)
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(10, 6))

sns.swarmplot(x='stat', y='value', data=melted_df, hue='Class')

plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ## Heatmaps
#
# A heatmap is a **<font color='##13e5e1'>graphical representation of data where the values of a matrix are represented as colors</font>**. Seaborn provides a convenient function to create heatmaps called `sns.heatmap()`.
#
# Here's an example of how to create a heatmap using Seaborn:

# %%
wine
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
corr = wine.corr(numeric_only=True)
corr
# Out:
#                                Alcohol  Malic acid       Ash  \
# Alcohol                       1.000000    0.094397  0.211545
# Malic acid                    0.094397    1.000000  0.164045
# Ash                           0.211545    0.164045  1.000000
# Alcalinity of ash            -0.310235    0.288500  0.443367
# Magnesium                     0.270798   -0.054575  0.286587
# Total phenols                 0.289101   -0.335167  0.128980
# Flavanoids                    0.236815   -0.411007  0.115077
# Nonflavanoid phenols         -0.155929    0.292977  0.186230
# Proanthocyanins               0.136698   -0.220746  0.009652
# Color intensity               0.546364    0.248985  0.258887
# Hue                          -0.071747   -0.561296 -0.074667
# OD280/OD315 of diluted wines  0.072343   -0.368710  0.003911
# Proline                       0.643720   -0.192011  0.223626
#
#                               Alcalinity of ash  Magnesium  Total phenols  \
# ...

# %%
sns.heatmap(corr)
plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Create a chart, ie. heatmap, showing the correlation between variables from the wine database:
# * in the squares, in addition to the color, put the correlation value
# * change the default color scale - e.g. green-blue, blue-red.
#
# <img src="https://drive.google.com/uc?export=view&id=1kKRYjYJU-Lkxu2WBNw5dLG_yOiLgTSc1" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="750px" hspace="30px" vspace="10px"/>

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(
    corr,
    annot=True,
    fmt='.2f',
    cmap='bwr',
)
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram with KDE
#
# In Seaborn, `displot()` is a function used to create a variety of plots for univariate distributions. It supports various types of plots, including histograms, **<font color='##13e5e1'>kernel density estimation (KDE) plots</font>**, and rug plots. When using `displot()` with the kind parameter set to 'kde', it generates a KDE plot.
#
# A KDE plot visualizes the **<font color='##13e5e1'>estimated probability density function of a continuous variable</font>**. It provides a smooth curve that approximates the underlying distribution of the data.

# %%
sns.displot(wine.Alcohol, kde=True)
plt.show()

# %% [markdown]
# ## Countplot
#
# A countplot is a **<font color='##13e5e1'>type of bar plot in which the count or frequency of each category</font>** in a categorical variable is represented by the height of the bars. Seaborn provides a convenient function called `sns.countplot()` to create countplots.

# %%
sns.countplot(x='Class', data=wine)
plt.show()

# %% [markdown]
# ## KDE & joint plots for 2D data
#
# To create a 2D kernel density estimation (KDE) plot in Seaborn, you can use the `sns.kdeplot()` function. This plot allows you to visualize the density of a bivariate dataset, representing the joint distribution of two continuous variables.

# %%
sns.kdeplot(
    data=wine,
    x='Alcohol',
    y='Magnesium'
)
plt.show()

# %%
sns.jointplot(
    data=wine,
    x='Alcohol',
    y='Magnesium'
)
plt.show()

# %% [markdown]
# ### **<font color='#306998'>TASK </font><font color='#ffd33b'>FOR YOU</font>**
#
# Update the above kdeplot chart and:
# * define the number of density levels as 10
# * add a color scale
#     * line color as well as fill between layers - the closer to the center the more intense the color
# * place a legend next to the graph with the color scale
#
# <img src="https://drive.google.com/uc?export=view&id=15FB8Svo8aHiKBLgNvPRMrQCFKp7rws9L" alt="Matplotlib: task for you" title="Matplotlib: task for you" align="center" width="750px" hspace="30px" vspace="10px"/>
#
# *Hint: Use cmap='viridis'*

# %%
from plotnine import *
from plotnine.data import mpg

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1UO2urRciECzoKE_vHy4RMGfFbkOWOGlW" alt="SDA logo" align="left" width="100px" hspace="10px" vspace="10px"/>
# <br>
#
# # TASKS

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.1</font>**
#
# For the following dataset:
# ```python
# from plotnine import *
# from plotnine.data import mpg
#
# mpg.head()
# ```
# Create a histogram chart of engine capacity ("displ"):
# * define the color of the bars
# * add axis description and chart title
# * change the theme of the chart (background, e.g. from dark gray to white without grid)

# %%
plt.figure(figsize=(12,6))
sns.set_style('dark')
sns.histplot(
    data=mpg,
    x='displ',
    color='b',
    bins=10
)
plt.grid(False)
plt.xlabel('Engine capacity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.2</font>**
#
# Create a graph showing the distribution of alcohol concentration in wines:
# * label the X, Y axes, and add a title
# * add a vertical line showing the average concentration value

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=wine, x='Alcohol', color='b')
plt.axvline(wine['Alcohol'].mean(), color='red', linestyle='--', linewidth=2)
plt.xlabel('Koncentrace alkoholu')
plt.ylabel('Frekvence')
plt.title('Distribuční graf')
plt.legend()
plt.show()

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.3</font>**
#
# Create a graph showing the number of wines according to class. Take care of the aesthetics of the graph.

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.4</font>**
#
# For the `mpg` dataset defined in task 2.1 create a jointplot showing the relationship of engine capacity ("displ") to the number of miles per gallon on the highway ("hwy"):
# 1. Include the class of car as the color.
# 1. Add a title to the graph and a graph grid, and change the font (note - different than in matplotlib).

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.5</font>**
#
# Create a kernel density estimate type graph showing the relationship between engine capacity and miles per gallon on the highway.
# 1. Add a fill to the graph and define the color scale to be different from the default.
# 1. Limit the area of the graph - X axis: (0.7), Y axis: (5.40).

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.6</font>**
#
# Create a heatmap graph for all continuous variables from the `mpg` set to show the correlation between the variables.
# * Add correlation values as annotations in the heatmap cells.
# * Define the color scale and format of the annotations.

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.7</font>**
#
# Create a graph showing the distribution of engine capacity ("displ") by vehicle class.
# 1. Include two chart types at once in the graph (e.g. boxplot + swarm)
# 1. Change the color palette

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.8</font>**
#
# Create an `lmplot` chart showing the relationship between engine capacity ("displ") and the number of cylinders ("cyl").
# 1. Take care of the aesthetics of the graph.
# 1. Add an annotation on the graph indicating the correlation between the variables shown.
#
# *Hint: you can use*
# ```python
# from scipy.stats import pearsonr
# corr, _ = pearsonr(mpg.displ, mpg.cyl)
# ```

# %% [markdown]
# ## **<font color='#306998'>TASK </font><font color='#ffd33b'>2.9</font>**
#
# Using the data below:
# 1. Create a graph of the relationship between beer consumption and wine consumption, mark the continent as the categories.
# 1. Create a graph with measures of the distribution of pure alcohol consumption per continent.

# %%
url='https://raw.githubusercontent.com/matzim95/ML-datasets/master/drinks.csv'
alcohols=pd.read_csv(url)
alcohols.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF
